# %%
import os,sys
from astropop.file_collection import FitsFileGroup
from astropy.io import fits
import numpy as np
from astropy.utils.data import get_pkg_data_filename
from astropy import units as u

# %%
#Salva um FitsFileGroup com todas as imagens da missão
data = os.path.expanduser('/media/fernando/KINGSTON/Doutorado/2025/20250309/')
pasta = ['sparc4acs1','sparc4acs2','sparc4acs3','sparc4acs4']
tipo = 'OBSTYPE'
tipo2= 'OBJECT'

# %%
#Contando os tipos de objeto no conjunto de imagens
label=[]
label2=[]
types1=[]
types12=[]
counter6=[]
counter62=[]
counter7=[]
counter72=[]
counter8=[]
for i in pasta:
    paste=os.path.join(data, i)

    e = []
    for diretorio, subpastas, arquivos in os.walk(paste):
        for arquivo in arquivos:
            d = os.path.join(diretorio, arquivo)
            e.append(d)

    novapasta=os.path.join(paste,'novapasta')
    os.makedirs(novapasta,exist_ok=True)
    num=len(e)
    num2=0
    for i in e:
        num2=num2+1
        print(f'{i}({num2}/{num})')
        f = fits.open(i)
        f[0].data = f[0].data[0]
        basename = os.path.basename(i)
        f.writeto(os.path.join(novapasta,basename))

    header = FitsFileGroup(novapasta) #FitsFileGroup(novapasta, database=nomedoarquivo.db)
    counter = ''
    counter2A= ''
    count = 0
    count2= 0
    counter3=0
    counter32=0
    counter4=[]
    counter42=[]
    counter5=[]
    counter52=[]
    types = [header[tipo][0]]
    types2=[header[tipo2][0]]
        
    for i in range(len(header)):
        counter2=header[tipo][i]
        counter22=header[tipo2][i]
        if counter2 != counter:
            count=count+1
            counter = header[tipo][i]
            for j in range(len(types)):
                if len(types) == 1:
                    if counter != types[j]:
                        types.append(counter)
                if len(types) == 2:
                    if counter != types[j] and counter != types[j-1]:
                        types.append(counter)
                if len(types) == 3:
                    if counter != types[j] and counter != types[j-1] and counter != types[j-2]:
                        types.append(counter)
                if len(types) == 4:
                    if counter != types[j] and counter != types[j-1] and counter != types[j-2] and counter != types[j-3]:
                        types.append(counter)
                if len(types) == 5:
                    if counter != types[j] and counter != types[j-1] and counter != types[j-2] and counter != types[j-3] and counter != types[j-4]:
                        types.append(counter)
                if len(types) == 6:
                    if counter != types[j] and counter != types[j-1] and counter != types[j-2] and counter != types[j-3] and counter != types[j-4] and counter != types[j-5]:
                        types.append(counter)
                if len(types) == 7:
                    if counter != types[j] and counter != types[j-1] and counter != types[j-2] and counter != types[j-3] and counter != types[j-4] and counter != types[j-5] and counter != types[j-6]:
                        types.append(counter)
                if len(types) == 8:
                    if counter != types[j] and counter != types[j-1] and counter != types[j-2] and counter != types[j-3] and counter != types[j-4] and counter != types[j-5] and counter != types[j-6] and counter != types[j-7]:
                        types.append(counter)
                if len(types) == 9:
                    if counter != types[j] and counter != types[j-1] and counter != types[j-2] and counter != types[j-3] and counter != types[j-4] and counter != types[j-5] and counter != types[j-6] and counter != types[j-7] and counter != types[j-8]:
                        types.append(counter)
                if len(types) == 10:
                    if counter != types[j] and counter != types[j-1] and counter != types[j-2] and counter != types[j-3] and counter != types[j-4] and counter != types[j-5] and counter != types[j-6] and counter != types[j-7] and counter != types[j-8] and counter != types[j-9]:
                        types.append(counter)
                if len(types) == 11:
                    if counter != types[j] and counter != types[j-1] and counter != types[j-2] and counter != types[j-3] and counter != types[j-4] and counter != types[j-5] and counter != types[j-6] and counter != types[j-7] and counter != types[j-8] and counter != types[j-9] and counter != types[j-10]:
                        types.append(counter)
                if len(types) == 12:
                    if counter != types[j] and counter != types[j-1] and counter != types[j-2] and counter != types[j-3] and counter != types[j-4] and counter != types[j-5] and counter != types[j-6] and counter != types[j-7] and counter != types[j-8] and counter != types[j-9] and counter != types[j-10] and counter != types[j-11]:
                        types.append(counter)
                if len(types) > 12:
                    print(f'Existem tipos de objeto demais. Verifique o código.')
            counter5.append(counter)
            if counter3 != 0:
                counter4.append(counter3)
            counter3=1
        else:
            counter3=counter3+1






        if counter22 != counter2A:
            count2=count2+1
            counter2A = header[tipo2][i]
            for j in range(len(types2)):
                if len(types2) == 1:
                    if counter2A != types2[j]:
                        types2.append(counter2A)
                if len(types2) == 2:
                    if counter2A != types2[j] and counter2A != types2[j-1]:
                        types2.append(counter2A)
                if len(types2) == 3:
                    if counter2A != types2[j] and counter2A != types2[j-1] and counter2A != types2[j-2]:
                        types2.append(counter2A)
                if len(types2) == 4:
                    if counter2A != types2[j] and counter2A != types2[j-1] and counter2A != types2[j-2] and counter2A != types2[j-3]:
                        types2.append(counter2A)
                if len(types2) == 5:
                    if counter2A != types2[j] and counter2A != types2[j-1] and counter2A != types2[j-2] and counter2A != types2[j-3] and counter2A != types2[j-4]:
                        types2.append(counter2A)
                if len(types2) == 6:
                    if counter2A != types2[j] and counter2A != types2[j-1] and counter2A != types2[j-2] and counter2A != types2[j-3] and counter2A != types2[j-4] and counter2A != types2[j-5]:
                        types2.append(counter2A)
                if len(types2) == 7:
                    if counter2A != types2[j] and counter2A != types2[j-1] and counter2A != types2[j-2] and counter2A != types2[j-3] and counter2A != types2[j-4] and counter2A != types2[j-5] and counter2A != types2[j-6]:
                        types2.append(counter2A)
                if len(types2) == 8:
                    if counter2A != types2[j] and counter2A != types2[j-1] and counter2A != types2[j-2] and counter2A != types2[j-3] and counter2A != types2[j-4] and counter2A != types2[j-5] and counter2A != types2[j-6] and counter2A != types2[j-7]:
                        types2.append(counter2A)
                if len(types2) == 9:
                    if counter2A != types2[j] and counter2A != types2[j-1] and counter2A != types2[j-2] and counter2A != types2[j-3] and counter2A != types2[j-4] and counter2A != types2[j-5] and counter2A != types2[j-6] and counter2A != types2[j-7] and counter2A != types2[j-8]:
                        types2.append(counter2A)
                if len(types2) == 10:
                    if counter2A != types2[j] and counter2A != types2[j-1] and counter2A != types2[j-2] and counter2A != types2[j-3] and counter2A != types2[j-4] and counter2A != types2[j-5] and counter2A != types2[j-6] and counter2A != types2[j-7] and counter2A != types2[j-8] and counter2A != types2[j-9]:
                        types2.append(counter2A)
                if len(types2) == 11:
                    if counter2A != types2[j] and counter2A != types2[j-1] and counter2A != types2[j-2] and counter2A != types2[j-3] and counter2A != types2[j-4] and counter2A != types2[j-5] and counter2A != types2[j-6] and counter2A != types2[j-7] and counter2A != types2[j-8] and counter2A != types2[j-9] and counter2A != types2[j-10]:
                        types2.append(counter2A)
                if len(types2) == 12:
                    if counter2A != types2[j] and counter2A != types2[j-1] and counter2A != types2[j-2] and counter2A != types2[j-3] and counter2A != types2[j-4] and counter2A != types2[j-5] and counter2A != types2[j-6] and counter2A != types2[j-7] and counter2A != types2[j-8] and counter2A != types2[j-9] and counter2A != types2[j-10] and counter2A != types2[j-11]:
                        types2.append(counter2A)
                if len(types2) > 12:
                    print(f'Existem tipos de objeto demais. Verifique o código.')
            counter52.append(counter2A)
            if counter32 != 0:
                counter42.append(counter32)
            counter32=1
        else:
            counter32=counter32+1

    counter4.append(counter3)
    label1 = len(types)
    label.append(label1)
    types1.append(types)
    counter6.append(counter4)
    counter7.append(counter5)
    
    counter42.append(counter32)
    label12 = len(types2)
    label2.append(label12)
    types12.append(types2)
    counter62.append(counter42)
    counter72.append(counter52)


    # Aqui os dados do header são lidos, alterados e adicionados de volta no header com os valores desejados.
    
    
    #NAXIS tem que ser '2' ao invés de '3'?
    #naxis = header["NAXIS"]
    #for i in range(len(header)):
    #    if naxis[i] != 2:
    #        naxis[i] = 2
    #for f, value in zip(header.files, naxis):
    #    fits.setval(f, 'NAXIS', value=value)
    
    
    #NAXIS3 não é pra existir
    #naxis3 = header["NAXIS3"]
    #for f, value in zip(header.files, naxis3):
    #    fits.delval(f, 'NAXIS3', value=value)
    
    
    #OBSERVER está vazio
    #observer = header['OBSERVER']
    #for f, value in zip(header.files, observer):
    #    fits.setval(f, 'OBSERVER', value=value)
    
    
    #Tem que adicionar o OBJECT
    #object = header['OBJECT']
    #print(object)
    
    
    #Não tem OBSLONG
    #obslong = []
    #for j in range(len(header)):
    #    obslong1 = -(45 + (34 + (57/60))/60)
    #    obslong.append(obslong1)
    #for f, value in zip(header.files, obslong):
    #    fits.setval(f, 'OBSLONG', value=value)
    #print(f'OBSLONG {obslong}')
    
    
    #Não tem INSTMODE
    #instmode = []
    #for j in range(len(header)):
    #    instmode1='PHOT'
    #    instmode.append(instmode1)
    #for f, value in zip(header.files, instmode):
    #    fits.setval(f, 'INSTMODE', value=value)
    #print(f'INSTMODE {instmode}')
    
    #Não tem INSTROT
    #instrot = header['INSTROT']
    
    
    #FILTER tem que virar 'unknown' ao invés de 'CLEAR'?
    #filter = header['FILTER']
    #print(filter)
    
    
    #OBSTYPE tem que virar 'FLAT' ao invés de 'DFLAT'?
    #obstype = header['OBSTYPE']
    #print(obstype)
    
    
    #CHANNEL está vazio
    #channel = []
    #filter = header['FILTER']
    #for j in range(len(header)):
    #    if filter[j] == 'U':
    #        channel1=0
    #    if filter[j] == 'B':
    #        channel1=5
    #    if filter[j] == 'V':
    #        channel1=3
    #    if filter[j] == 'R':
    #        channel1=2
    #    if filter[j] == 'I':
    #        channel1=1
    #    else:
    #        channel1=4
    #    channel.append(channel1)
    #for f, value in zip(header.files, channel):
    #    fits.setval(f, 'CHANNEL', value=value)
    #print(f'CHANNEL {channel}')
    #counter8.append(channel)
    
    
    #SERN tem que virar CCDSERN
    #ccdsern = header['SERN']
    #for f, value in zip(header.files, ccdsern):
    #    fits.setval(f, 'CCDSERN', value=value)
    #print(f'CCDSERN {ccdsern}')
    
    
    #DATE tem que virar DATE-OBS
    #dateobs = header['DATE']
    #for f, value in zip(header.files, dateobs):
    #    fits.setval(f, 'DATE-OBS', value=value)
    #print(f'DATE-OBS {dateobs}')
    
    
    #Não tem UTTIME
    #uttime = header['UTTIME']
    
    
    #UTDATE está vazio
    #utdate = header['UTDATE']
    
    
    #Não tem NCYCLES
    #ncycles = header['NCYCLES']
    
    
    #Não tem NSEQ
    #nseq = header['NSEQ']
    
    
    #NEXPSEQ tem que virar NFRAMES
    #nexpseq = header['NEXPSEQ']
    
    
    #SEQINDEX tem que virar FRAMEIND
    #seqindex = header['SEQINDEX']
    
    
    #EXPTIME está com um '.' no final que talvez não deva existir #############################################
    #exptime = header['EXPTIME']
    
    
    #ACQMODE tem que ser 'Kinetic ' ao invés de 'kinetics'?
    #acqmode = header['ACQMODE']
    
    
    #READOUT tem que virar READRATE e a unidade tem que ser removida
    #readrate = header['READOUT']
    #for j in range(len(header)):
    #    readrate[j] = readrate[j].replace(" MHz", "")
    #    readrate[j] = float(readrate[j])
    #for f, value in zip(header.files, readrate):
    #    fits.setval(f, 'READRATE', value=value)
    #print(f'READRATE {readrate}')
    
    
    #VSHIFT tem que sair das aspas ('')? ######################################################################
    #vshift = header['VSHIFT']
    
    
    #COOLER tem que virar 'T' ao invés de 'ON' e tem que ser fora das aspas
    #cooler = header['COOLER']
    
    
    #TEMP tem que virar CCDTEMP
    #temp = header['TEMP']
    
    
    #FRAME_T tem que virar FRAMETRF e o valor tem que ser 'T' fora das aspas ao invés de 'ON'
    #frame_t = header['FRAME_T']
    
    
    #VCLOCK tem que virar VCLKAMP
    #vclkamp = header['VCLOCK']
    #for f, value in zip(header.files, vclkamp):
    #    fits.setval(f, 'VCLKAMP', value=value)
    #print(f'VCLKAMP {vclkamp}')
    
    
    #Adicionar o valor do GAIN
    #gain = []
    #for j in range(len(header)):
    #    gain1=0.800
    #    gain.append(gain1)
    #for f, value in zip(header.files, gain):
    #    fits.setval(f, 'GAIN', value=value)
    #print(f'GAIN {gain}')
    
    
    #Adicionar o  valor do RDNOISE
    #rdnoise = []
    #for j in range(len(header)):
    #    rdnoise1=4.76
    #    rdnoise.append(rdnoise1)
    #for f, value in zip(header.files, rdnoise):
    #    fits.setval(f, 'RDNOISE', value=value)
    #print(f'RDNOISE {rdnoise}')
    
    
    #Não tem EQUINOX
    #equinox = header['EQUINOX']
    
    
    #Adicionar o valor de TELFOCUS (ou seria TELFOC?)
    #telfoc = header['TELFOC']
    
    
    #Não tem TCSHA
    #tcsha = header['TCSHA']
    
    
    #Mudar o valor de TCSDATE
    #tcsdate = header['TCSDATE']
    
    
    #GFOCUS tem que virar GFOC e o valor tem que ser corrigido
    #gfocus = header['GFOCUS']
    
    
    #Não tem GUIDERA
    #guidera = header['GUIDERA']
    
    
    #Não tem GUIDEDEC
    #guidedec = header['GUIDEDEC']
    
    
    #TEMPEXT tem que virar EXTTEMP e o valor tem que sair das aspas
    #tempext = header['TEMPEXT']
    
    
    #Corrigir o valor de AIRMASS
    #airmass = header['AIRMASS']
    
    
    #PRESSURE tem que sair das aspas
    #pressure = header['PRESSURE']
    
    
    #HUMIDITY tem que sair das aspas
    #humidity = header['HUMIDITY']
    
    
    #Não tem ACSMODE
    #acsmode = header['ACSMODE']
    
    
    #Não tem ICSMODE
    #icsmode = header['ICSMODE']
    
    
    #Não tem TCSMODE
    #tcsmode = header['TCSMODE']
    
    
    #Não tem WPSEL
    #wpsel = []
    #for j in range(len(header)):
    #    wpsel1='NONE'
    #    wpsel.append(wpsel1)
    #for f, value in zip(header.files, wpsel):
    #    fits.setval(f, 'WPSEL', value=value)
    #print(f'WPSEL {wpsel}')
    
    
    #Não tem WPPOS
    #wppos = []
    #for j in range(len(header)):
    #    wppos1=0
    #    wppos.append(wppos1)
    #for f, value in zip(header.files, wppos):
    #    fits.setval(f, 'WPPOS', value=value)
    #print(f'WPPOS {wppos}')
    
    
    #Não tem CALW
    #calw = []
    #for j in range(len(header)):
    #    calw1='OFF'
    #    calw.append(calw1)
    #for f, value in zip(header.files, calw):
    #    fits.setval(f, 'CALW', value=value)
    #print(f'CALW {calw}')
    
    
    #Não tem ASEL
    #asel = []
    #for j in range(len(header)):
    #    asel1=False
    #    asel.append(asel1)
    #for f, value in zip(header.files, asel):
    #    fits.setval(f, 'ASEL', value=value)
    #print(f'ASEL {asel}')
    
    
    #Não tem GMIR
    #gmir = header['GMIR']
    
    
    #Não tem GFOC
    #gfoc = header['GFOC']
    
    #obstype = header['OBSTYPE']
    #for j in range(len(header)):
    #    obstype[j] = obstype[j].replace("DFLAT", "FLAT")
    #for f, value in zip(header.files, obstype):
    #    fits.setval(f, 'OBSTYPE', value=value)
    #print(f'OBSTYPE {obstype}')
# Out:
# /media/fernando/KINGSTON/Doutorado/2025/20250309/sparc4acs1/20250309_s4c1_000038_velal2.fits(1/812)
# /media/fernando/KINGSTON/Doutorado/2025/20250309/sparc4acs1/20250309_s4c1_000039_velal2.fits(2/812)
# /media/fernando/KINGSTON/Doutorado/2025/20250309/sparc4acs1/20250309_s4c1_000040_velal2.fits(3/812)
# /media/fernando/KINGSTON/Doutorado/2025/20250309/sparc4acs1/20250309_s4c1_000041_velal2.fits(4/812)
# /media/fernando/KINGSTON/Doutorado/2025/20250309/sparc4acs1/20250309_s4c1_000042_velal2.fits(5/812)
# /media/fernando/KINGSTON/Doutorado/2025/20250309/sparc4acs1/20250309_s4c1_000043_velal2.fits(6/812)
# /media/fernando/KINGSTON/Doutorado/2025/20250309/sparc4acs1/20250309_s4c1_000044_velal2.fits(7/812)
# /media/fernando/KINGSTON/Doutorado/2025/20250309/sparc4acs1/20250309_s4c1_000045_velal2.fits(8/812)
# /media/fernando/KINGSTON/Doutorado/2025/20250309/sparc4acs1/20250309_s4c1_000046_velal2.fits(9/812)
# ...

# %%
#Print dos resultados para o tipo
for i in range(len(label)):
    print(f'Existem {len(types1[i])} tipos de {tipo} no conjunto de dados em {pasta[i]}:')
    print(types1[i])
    print(f'Sendo que a ordem de capturas foi:')
    counter9=0
    for j in range(len(counter7[i])):
        print(f'({counter6[i][j]}){counter7[i][j]} (Channel = {counter8[i][counter9:counter9+counter6[i][j]]}).')
        counter9=counter9+counter6[i][j]
    print(f'\n')
# Out:
# Existem 3 tipos de OBSTYPE no conjunto de dados em sparc4acs1:
# ['OBJECT', 'ZERO', 'FLAT']
# Sendo que a ordem de capturas foi:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 8
#       6 counter9=0
#       7 for j in range(len(counter7[i])):
# ----> 8     print(f'({counter6[i][j]}){counter7[i][j]} (Channel = {counter8[i][counter9:counter9+counter6[i][j]]}).')
#       9     counter9=counter9+counter6[i][j]
#      10 print(f'\n')
#
# IndexError: list index out of range

# %%
#Print dos resultados para o tipo2
for i in range(len(label2)):
    print(f'Existem {len(types12[i])} tipos de {tipo2} no conjunto de dados em {pasta[i]}:')
    print(types12[i])
    print(f'Sendo que a ordem de capturas foi:')
    counter9=0
    for j in range(len(counter72[i])):
        print(f'({counter62[i][j]}){counter72[i][j]} (Channel = {counter8[i][counter9:counter9+counter62[i][j]]}).')
        counter9=counter9+counter62[i][j]
    print(f'\n')
# Out:
# Existem 6 tipos de OBJECT no conjunto de dados em sparc4acs1:
# ['Vela1-95', 'HD298383', 'WD1036-204', 'V1025 Cen', 'ZERO', 'DOMEFLAT']
# Sendo que a ordem de capturas foi:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 8
#       6 counter9=0
#       7 for j in range(len(counter72[i])):
# ----> 8     print(f'({counter62[i][j]}){counter72[i][j]} (Channel = {counter8[i][counter9:counter9+counter62[i][j]]}).')
#       9     counter9=counter9+counter62[i][j]
#      10 print(f'\n')
#
# IndexError: list index out of range
