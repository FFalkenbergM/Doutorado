# %%
import os
import numpy as np
from astropy import units as u

# astropop used modules
from astropop.image import imcombine, processing, imarith
from astropop.framedata import read_framedata
from astropop.image.register import register_framedata_list
from astropop.photometry import background, starfind
from astropop.logger import logger
logger.setLevel('INFO')

# Directories where we will storefiles
base_dir = os.path.expanduser('/media/fernando/SAMSUNG/Doutorado/J1955_2022/')

dir_0613 = os.path.join(base_dir, '20220613')
dir_0614 = os.path.join(base_dir, '20220614')
dir_0615 = os.path.join(flat_dir, '20220615')
dir_0619 = os.path.join(flat_dir, '20220619')

# %% [markdown]
# # IGR 1955 I filter

# %%
from astropop.file_collection import FitsFileGroup
igr1955_fg = FitsFileGroup(base_dir)
print(f'Número de imagens: {len(igr1955_fg)}')

#igr1955_SIMPLE = igr1955_fg.filtered({'SIMPLE':T})
#print(f'SIMPLE:            {len(igr1955_SIMPLE)}')

igr1955_BITPIX = igr1955_fg.filtered({'BITPIX':16})
print(f'BITPIX:            {len(igr1955_BITPIX)}')

igr1955_NAXIS = igr1955_fg.filtered({'NAXIS':2})
print(f'NAXIS:             {len(igr1955_NAXIS)}')

igr1955_NAXIS1 = igr1955_fg.filtered({'NAXIS1':1024})
print(f'NAXIS1:            {len(igr1955_NAXIS1)}')

igr1955_NAXIS2 = igr1955_fg.filtered({'NAXIS2':1024})
print(f'NAXIS2:            {len(igr1955_NAXIS2)}')

#igr1955_EXTEND = igr1955_fg.filtered({'EXTEND':T})
#print(f'EXTEND:            {len(igr1955_EXTEND)}')

#igr1955_COMMENT = igr1955_fg.filtered({'COMMENT':'igr1955'})
#print(f'COMMENT:           {len(igr1955_COMMENT)}')

igr1955_BZERO = igr1955_fg.filtered({'BZERO':32768})
print(f'BZERO:             {len(igr1955_BZERO)}')

igr1955_BSCALE = igr1955_fg.filtered({'BSCALE':1})
print(f'BSCALE:            {len(igr1955_BSCALE)}')

#igr1955_FILENAME = igr1955_fg.filtered({'FILENAME':''})
#print(f'FILENAME:          {len(igr1955_FILENAME)}')

igr1955_OBSERVER = igr1955_fg.filtered({'OBSERVER':''})
print(f'OBSERVER:          {len(igr1955_OBSERVER)}')

igr1955_OBJECT = igr1955_fg.filtered({'OBJECT':'IGR19552+0044'})
print(f'OBJECT:            {len(igr1955_OBJECT)}')

igr1955_ACQMODE = igr1955_fg.filtered({'ACQMODE':'Single'})
print(f'ACQMODE:           {len(igr1955_ACQMODE)}')

igr1955_READMODE = igr1955_fg.filtered({'READMODE':'Image'})
print(f'READMODE:          {len(igr1955_READMODE)}')

igr1955_IMGRECT = igr1955_fg.filtered({'IMGRECT':'1, 1024,1024, 1'})
print(f'IMGRECT:           {len(igr1955_IMGRECT)}')

igr1955_HBIN = igr1955_fg.filtered({'HBIN':'1'})
print(f'HBIN:              {len(igr1955_HBIN)}')

igr1955_VBIN = igr1955_fg.filtered({'VBIN':'1'})
print(f'VBIN:              {len(igr1955_VBIN)}')

igr1955_SUBRECT = igr1955_fg.filtered({'SUBRECT':'1, 1024,1024,1'})
print(f'SUBRECT:           {len(igr1955_SUBRECT)}')

igr1955_DATATYPE = igr1955_fg.filtered({'DATATYPE':'Counts'})
print(f'DATATYPE:          {len(igr1955_DATATYPE)}')

igr1955_XTYPE = igr1955_fg.filtered({'XTYPE':'Pixel number'})
print(f'XTYPE:             {len(igr1955_XTYPE)}')

igr1955_XUNIT = igr1955_fg.filtered({'XUNIT':0})
print(f'XUNIT:             {len(igr1955_XUNIT)}')

igr1955_RAYWAVE = igr1955_fg.filtered({'RAYWAVE':0.})
print(f'RAYWAVE:           {len(igr1955_RAYWAVE)}')

igr1955_CALBWVNM = igr1955_fg.filtered({'CALBWVNM':0})
print(f'CALBWVNM:          {len(igr1955_CALBWVNM)}')

igr1955_TRIGGER = igr1955_fg.filtered({'TRIGGER':'Internal'})
print(f'TRIGGER:           {len(igr1955_TRIGGER)}')

igr1955_CALIB = igr1955_fg.filtered({'CALIB':'0.,1.,0.,0.'})
print(f'CALIB:             {len(igr1955_CALIB)}')

igr1955_DLLVER = igr1955_fg.filtered({'DLLVER':'2.102.30024.0'})
print(f'DLLVER:            {len(igr1955_DLLVER)}')

igr1955_EXPOSURE = igr1955_fg.filtered({'EXPOSURE':'20,00000'})
print(f'EXPOSURE:          {len(igr1955_EXPOSURE)}')

igr1955_TEMP = igr1955_fg.filtered({'TEMP':'-75,1'})
print(f'TEMP:              {len(igr1955_TEMP)}')

igr1955_READTIME = igr1955_fg.filtered({'READTIME':1.0E-06})
print(f'READTIME:          {len(igr1955_READTIME)}')

igr1955_OPERATN = igr1955_fg.filtered({'OPERATN':4})
print(f'OPERATN:           {len(igr1955_OPERATN)}')

igr1955_GAIN = igr1955_fg.filtered({'GAIN':'0.77'})
print(f'GAIN:              {len(igr1955_GAIN)}')

igr1955_EMREALGN = igr1955_fg.filtered({'EMREALGN':0})
print(f'EMREALGN:          {len(igr1955_EMREALGN)}')

igr1955_VCLKAMP = igr1955_fg.filtered({'VCLKAMP':0})
print(f'VCLKAMP:           {len(igr1955_VCLKAMP)}')

igr1955_VSHIFT = igr1955_fg.filtered({'VSHIFT':'4.33E-06'})
print(f'VSHIFT:            {len(igr1955_VSHIFT)}')

igr1955_OUTPTAMP = igr1955_fg.filtered({'OUTPTAMP':'Conventional'})
print(f'OUTPTAMP:          {len(igr1955_OUTPTAMP)}')

igr1955_PREAMP = igr1955_fg.filtered({'PREAMP':'2x'})
print(f'PREAMP:            {len(igr1955_PREAMP)}')

igr1955_SERNO = igr1955_fg.filtered({'SERNO':'10671'})
print(f'SERNO:             {len(igr1955_SERNO)}')

igr1955_UNSTTEMP = igr1955_fg.filtered({'UNSTTEMP':'-999'})
print(f'UNSTTEMP:          {len(igr1955_UNSTTEMP)}')

#igr1955_BLCLAMP = igr1955_fg.filtered({'BLCLAMP':F})
#print(f'BLCLAMP:           {len(igr1955_BLCLAMP)}')

igr1955_PRECAN = igr1955_fg.filtered({'PRECAN':0})
print(f'PRECAN:            {len(igr1955_PRECAN)}')

igr1955_FLIPX = igr1955_fg.filtered({'FLIPX':0})
print(f'FLIPX:             {len(igr1955_FLIPX)}')

igr1955_FLIPY = igr1955_fg.filtered({'FLIPY':0})
print(f'FLIPY:             {len(igr1955_FLIPY)}')

igr1955_CNTCVTMD = igr1955_fg.filtered({'CNTCVTMD':0})
print(f'CNTCVTMD:          {len(igr1955_CNTCVTMD)}')

igr1955_CNTCVT = igr1955_fg.filtered({'CNTCVT':1})
print(f'CNTCVT:            {len(igr1955_CNTCVT)}')

igr1955_DTNWLGTH = igr1955_fg.filtered({'DTNWLGTH':500.})
print(f'DTNWLGTH:          {len(igr1955_DTNWLGTH)}')

igr1955_SNTVTY = igr1955_fg.filtered({'SNTVTY':0.77})
print(f'SNTVTY:            {len(igr1955_SNTVTY)}')

igr1955_SPSNFLTR = igr1955_fg.filtered({'SPSNFLTR':0})
print(f'SPSNFLTR:          {len(igr1955_SPSNFLTR)}')

igr1955_THRSHLD = igr1955_fg.filtered({'THRSHLD':0.})
print(f'THRSHLD:           {len(igr1955_THRSHLD)}')

igr1955_PCNTENLD = igr1955_fg.filtered({'PCNTENLD':0})
print(f'PCNTENLD:          {len(igr1955_PCNTENLD)}')

igr1955_NSETHSLD = igr1955_fg.filtered({'NSETHSLD':0})
print(f'NSETHSLD:          {len(igr1955_NSETHSLD)}')

igr1955_PTNTHLD1 = igr1955_fg.filtered({'PTNTHLD1':0.})
print(f'PTNTHLD1:          {len(igr1955_PTNTHLD1)}')

igr1955_PTNTHLD2 = igr1955_fg.filtered({'PTNTHLD2':0.})
print(f'PTNTHLD2:          {len(igr1955_PTNTHLD2)}')

igr1955_PTNTHLD3 = igr1955_fg.filtered({'PTNTHLD3':0.})
print(f'PTNTHLD3:          {len(igr1955_PTNTHLD3)}')

igr1955_PTNTHLD4 = igr1955_fg.filtered({'PTNTHLD4':0.})
print(f'PTNTHLD4:          {len(igr1955_PTNTHLD4)}')

igr1955_AVGFTRMD = igr1955_fg.filtered({'AVGFTRMD':0})
print(f'AVGFTRMD:          {len(igr1955_AVGFTRMD)}')

igr1955_AVGFCTR = igr1955_fg.filtered({'AVGFCTR':1})
print(f'AVGFCTR:           {len(igr1955_AVGFCTR)}')

igr1955_FRMCNT = igr1955_fg.filtered({'FRMCNT':1})
print(f'FRMCNT:            {len(igr1955_FRMCNT)}')

igr1955_PORTMODE = igr1955_fg.filtered({'PORTMODE':-1})
print(f'PORTMODE:          {len(igr1955_PORTMODE)}')

igr1955_LSHEIGHT = igr1955_fg.filtered({'LSHEIGHT':0})
print(f'LSHEIGHT:          {len(igr1955_LSHEIGHT)}')

igr1955_LSSPEED = igr1955_fg.filtered({'LSSPEED':0.})
print(f'LSSPEED:           {len(igr1955_LSSPEED)}')

igr1955_LSALTDIR = igr1955_fg.filtered({'LSALTDIR':0})
print(f'LSALTDIR:          {len(igr1955_LSALTDIR)}')

igr1955_LSCTRL = igr1955_fg.filtered({'LSCTRL':0})
print(f'LSCTRL:            {len(igr1955_LSCTRL)}')

igr1955_LSDIR = igr1955_fg.filtered({'LSDIR':0})
print(f'LSDIR:             {len(igr1955_LSDIR)}')

igr1955_FKSMODE = igr1955_fg.filtered({'FKSMODE':0})
print(f'FKSMODE:           {len(igr1955_FKSMODE)}')

igr1955_FKTMODE = igr1955_fg.filtered({'FKTMODE':0})
print(f'FKTMODE:           {len(igr1955_FKTMODE)}')

igr1955_USERTXT1 = igr1955_fg.filtered({'USERTXT1':''})
print(f'USERTXT1:          {len(igr1955_USERTXT1)}')

igr1955_USERTXT2 = igr1955_fg.filtered({'USERTXT2':''})
print(f'USERTXT2:          {len(igr1955_USERTXT2)}')

igr1955_USERTXT3 = igr1955_fg.filtered({'USERTXT3':''})
print(f'USERTXT3:          {len(igr1955_USERTXT3)}')

igr1955_USERTXT4 = igr1955_fg.filtered({'USERTXT4':''})
print(f'USERTXT4:          {len(igr1955_USERTXT4)}')

#igr1955_DATE = igr1955_fg.filtered({'DATE':''})
#print(f'DATE:              {len(igr1955_DATE)}')

#igr1955_FRAME = igr1955_fg.filtered({'FRAME':''})
#print(f'FRAME:             {len(igr1955_FRAME)}')

igr1955_ESHTMODE = igr1955_fg.filtered({'ESHTMODE':0})
print(f'ESHTMODE:          {len(igr1955_ESHTMODE)}')

igr1955_IRIGDATA = igr1955_fg.filtered({'IRIGDATA':''})
print(f'IRIGDATA:          {len(igr1955_IRIGDATA)}')

igr1955_DETECTOR = igr1955_fg.filtered({'DETECTOR':''})
print(f'DETECTOR:          {len(igr1955_DETECTOR)}')

igr1955_EXPTIME = igr1955_fg.filtered({'EXPTIME':'20,00000'})
print(f'EXPTIME:           {len(igr1955_EXPTIME)}')

igr1955_CAMGAIN = igr1955_fg.filtered({'CAMGAIN':'2x'})
print(f'CAMGAIN:           {len(igr1955_CAMGAIN)}')

#igr1955_DATE_OBS = igr1955_fg.filtered({'DATE-OBS':''})
#print(f'DATE-OBS:          {len(igr1955_DATE_OBS)}')

#igr1955_DEC = igr1955_fg.filtered({'DEC':''})
#print(f'DEC:               {len(igr1955_DEC)}')

igr1955_EPOCH = igr1955_fg.filtered({'EPOCH':'2000.0'})
print(f'EPOCH:             {len(igr1955_EPOCH)}')

#igr1955_AIRMASS = igr1955_fg.filtered({'AIRMASS':''})
#print(f'AIRMASS:           {len(igr1955_AIRMASS)}')

#igr1955_JD = igr1955_fg.filtered({'JD':''})
#print(f'JD:                {len(igr1955_JD)}')

#igr1955_ST = igr1955_fg.filtered({'ST':''})
#print(f'ST:                {len(igr1955_ST)}')

#igr1955_HA = igr1955_fg.filtered({'HA':''})
#print(f'HA:                {len(igr1955_HA)}')

#igr1955_IMAGE = igr1955_fg.filtered({'IMAGE':''})
#print(f'IMAGE:             {len(igr1955_IMAGE)}')

igr1955_TELESCOP = igr1955_fg.filtered({'TELESCOP':'1.60m focal reducer'})
print(f'TELESCOP:          {len(igr1955_TELESCOP)}')

igr1955_PLATESCL = igr1955_fg.filtered({'PLATESCL':'0.36'})
print(f'PLATESCL:          {len(igr1955_PLATESCL)}')

igr1955_INSTRUME = igr1955_fg.filtered({'INSTRUME':'Cam1+RF+Ixon'})
print(f'INSTRUME:          {len(igr1955_INSTRUME)}')

igr1955_RDNOISE = igr1955_fg.filtered({'RDNOISE':'4.47'})
print(f'RDNOISE:           {len(igr1955_RDNOISE)}')

#igr1955_LAMINA = igr1955_fg.filtered({'LAMINA':''})
#print(f'LAMINA:            {len(igr1955_LAMINA)}')

#igr1955_LAM_POS = igr1955_fg.filtered({'LAM-POS':''})
#print(f'LAM-POS:           {len(igr1955_LAM_POS)}')

igr1955_FILTER = igr1955_fg.filtered({'FILTER':'F4'})
print(f'FILTER:            {len(igr1955_FILTER)}')

igr1955_FIL_POS = igr1955_fg.filtered({'FIL-POS':'4'})
print(f'FIL-POS:           {len(igr1955_FIL_POS)}')

igr1955_W_BAR = igr1955_fg.filtered({'W-BAR':'761,5'})
print(f'W_BAR:             {len(igr1955_W_BAR)}')

igr1955_W_TEMP = igr1955_fg.filtered({'W-TEMP':'19,1'})
print(f'W_TEMP:            {len(igr1955_W_TEMP)}')

igr1955_W_HUM = igr1955_fg.filtered({'W-HUM':'61'})
print(f'W_HUM:             {len(igr1955_W_HUM)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1145'})
print(f'FOCUSVAL1145:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1146'})
print(f'FOCUSVAL1146:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1147'})
print(f'FOCUSVAL1147:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1148'})
print(f'FOCUSVAL1148:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1149'})
print(f'FOCUSVAL1149:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1150'})
print(f'FOCUSVAL1150:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1151'})
print(f'FOCUSVAL1151:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1152'})
print(f'FOCUSVAL1152:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1153'})
print(f'FOCUSVAL1153:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1154'})
print(f'FOCUSVAL1154:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1155'})
print(f'FOCUSVAL1155:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1156'})
print(f'FOCUSVAL1156:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1157'})
print(f'FOCUSVAL1157:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1158'})
print(f'FOCUSVAL1158:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1159'})
print(f'FOCUSVAL1159:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1160'})
print(f'FOCUSVAL1160:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1161'})
print(f'FOCUSVAL1161:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1162'})
print(f'FOCUSVAL1162:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1163'})
print(f'FOCUSVAL1163:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1164'})
print(f'FOCUSVAL1164:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1165'})
print(f'FOCUSVAL1165:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1166'})
print(f'FOCUSVAL1166:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1167'})
print(f'FOCUSVAL1167:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1168'})
print(f'FOCUSVAL1168:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1169'})
print(f'FOCUSVAL1169:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1170'})
print(f'FOCUSVAL1170:       {len(igr1955_FOCUSVAL)}')

igr1955_FOCUSVAL = igr1955_fg.filtered({'FOCUSVAL':'1171'})
print(f'FOCUSVAL1171:       {len(igr1955_FOCUSVAL)}')
# Out:
# Número de imagens: 758
# BITPIX:            758
# NAXIS:             758
# NAXIS1:            758
# NAXIS2:            758
# BZERO:             758
# BSCALE:            758
# HEAD:              758
# ACQMODE:           758
# READMODE:          758
# IMGRECT:           758
# HBIN:              758
# VBIN:              758
# SUBRECT:           758
# DATATYPE:          758
# XTYPE:             758
# XUNIT:             758
# RAYWAVE:           758
# CALBWVNM:          758
# TRIGGER:           758
# CALIB:             758
# DLLVER:            758
# EXPOSURE:          758
# TEMP:              758
# READTIME:          758
# OPERATN:           758
# GAIN:              758
# EMREALGN:          758
# VCLKAMP:           758
# VSHIFT:            758
# OUTPTAMP:          758
# PREAMP:            758
# SERNO:             758
# UNSTTEMP:          758
# PRECAN:            758
# FLIPX:             758
# FLIPY:             758
# CNTCVTMD:          758
# CNTCVT:            758
# DTNWLGTH:          758
# ...
